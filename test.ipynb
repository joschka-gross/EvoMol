# %%
from evomol.molgraphops.molgraph import MolGraph, MolGraphBuilder

# %%
from rdkit import Chem

# testing purposes
aspirin_smiles = "CC(=O)Oc1ccccc1C(=O)O"
aspirin = Chem.MolFromSmiles(aspirin_smiles)

# %%
from rdkit.Chem import Draw

# %%
# reference
Draw.MolToImage(aspirin)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300 at 0x165924920>

# %%
from evomol.ga import Population, run_ga, PopMember, Logger
from evomol.ga.population import compare_generated_to_reference, pop_minus

# %%
test_pop = Population([PopMember(aspirin_smiles)]).repeat(10)

# %% [markdown]
# ### Test simple substitution action space

# %%
from evomol.ga.defined_action_spaces import SubstitutionMovingOnlyActionSpace
# Out:
# SYMBOLS LIST : ['Cl', 'F', 'O', 'Br', 'N']
# SYMBOLS LIST : ['Cl', 'F', 'O', 'Br', 'N']

# %%
logger = Logger()
run_ga(test_pop, SubstitutionMovingOnlyActionSpace, 30, logger)
# Out:
# Substitute atom of id 3 and type O by F
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type F by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type N by F
# Substitute atom of id 12 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 2 and type O by N
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 11 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 12 and type O by F
# Substitute atom of id 6 and type F by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 6 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 8 and type O by N
# Substitute atom of id 12 and type O by F
# Substitute atom of id 10 and type O by N
# Substitute atom of id 12 and type O by F
# Substitute atom of id 8 and type O by F
# Substitute atom of id 11 and type O by N
# Substitute atom of id 8 and type O by N
# Substitute atom of id 6 and type O by N
# Substitute atom of id 8 and type O by N
# Substitute atom of id 12 and type F by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type F by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 10 and type O by N
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 2 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 7 and type O by F
# Substitute atom of id 10 and type O by N
# Substitute atom of id 5 and type O by F
# Substitute atom of id 12 and type O by N
# Substitute atom of id 5 and type O by Br
# Substitute atom of id 0 and type N by F
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 0 and type N by O
# Substitute atom of id 10 and type O by N
# Substitute atom of id 4 and type F by N
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 4 and type F by O
# Substitute atom of id 6 and type N by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type F by N
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 12 and type O by F
# Substitute atom of id 8 and type Br by F
# Substitute atom of id 8 and type F by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 12 and type F by O
# Substitute atom of id 8 and type O by F
# Substitute atom of id 12 and type F by N
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 8 and type O by Br
# Substitute atom of id 2 and type O by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 5 and type N by O
# Substitute atom of id 12 and type F by Br
# Substitute atom of id 12 and type F by N
# Substitute atom of id 8 and type O by F
# Substitute atom of id 12 and type F by N
# Substitute atom of id 8 and type O by Br
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 5 and type O by N
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 5 and type O by N
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type F by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 8 and type O by F
# Substitute atom of id 12 and type F by Br
# Substitute atom of id 12 and type F by N
# Substitute atom of id 8 and type O by N
# Substitute atom of id 6 and type N by O
# Substitute atom of id 12 and type F by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 7 and type N by O
# Substitute atom of id 7 and type N by Br
# Substitute atom of id 11 and type N by Br
# Substitute atom of id 11 and type N by F
# Substitute atom of id 2 and type N by O
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 10 and type N by F
# Substitute atom of id 3 and type O by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 10 and type Br by F
# Substitute atom of id 2 and type N by O
# Substitute atom of id 7 and type N by Br
# Substitute atom of id 7 and type N by F
# Substitute atom of id 11 and type N by F
# Substitute atom of id 7 and type F by N
# Substitute atom of id 7 and type N by F
# Substitute atom of id 3 and type O by N
# Substitute atom of id 5 and type N by O
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 5 and type N by O
# Substitute atom of id 3 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 4 and type F by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 9 and type N by O
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 10 and type Br by F
# Substitute atom of id 2 and type O by N
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 2 and type N by O
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 12 and type F by N
# Substitute atom of id 3 and type N by O
# Substitute atom of id 3 and type O by N
# Substitute atom of id 11 and type O by F
# Substitute atom of id 11 and type F by O
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 11 and type F by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 9 and type O by N
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 11 and type N by F
# Substitute atom of id 11 and type F by O
# Substitute atom of id 5 and type N by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 5 and type N by O
# Substitute atom of id 10 and type N by F
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 8 and type O by N
# Substitute atom of id 10 and type N by F
# Substitute atom of id 10 and type F by Br
# Substitute atom of id 12 and type N by F
# Substitute atom of id 12 and type F by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 2 and type O by N
# Substitute atom of id 5 and type O by N
# Substitute atom of id 8 and type O by N
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 8 and type O by N
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 3 and type N by O
# Substitute atom of id 2 and type O by N
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 3 and type N by F
# Substitute atom of id 3 and type F by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 5 and type O by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 2 and type N by O
# Substitute atom of id 2 and type N by O
# Substitute atom of id 3 and type O by N
# Substitute atom of id 2 and type N by O
# Substitute atom of id 2 and type N by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 5 and type O by N
# Substitute atom of id 11 and type O by F
# Substitute atom of id 2 and type N by O
# Substitute atom of id 5 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 10 and type N by F
# Substitute atom of id 8 and type O by N
# Substitute atom of id 10 and type N by F
# Substitute atom of id 11 and type Br by N
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 0 and type N by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 12 and type F by O
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 10 and type O by N
# Substitute atom of id 2 and type N by O
# Substitute atom of id 7 and type O by F
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 3 and type N by Br
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type F by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 2 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type F by O
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 7 and type O by F
# Substitute atom of id 12 and type O by N
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 10 and type O by F
# Substitute atom of id 12 and type O by N
# Substitute atom of id 10 and type F by O
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 6 and type O by Br
# Substitute atom of id 8 and type O by N
# Substitute atom of id 8 and type O by N
# Substitute atom of id 8 and type N by O
# Substitute atom of id 6 and type O by N
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 3 and type N by O
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 4 and type Br by N
# Substitute atom of id 9 and type N by O
# Substitute atom of id 6 and type O by N
# Substitute atom of id 4 and type Br by N
# Substitute atom of id 4 and type Br by F
# Substitute atom of id 6 and type O by F
# Substitute atom of id 4 and type Br by F
# Substitute atom of id 10 and type N by O
# Substitute atom of id 10 and type N by F
# Substitute atom of id 4 and type O by N
# Substitute atom of id 4 and type N by O
# Substitute atom of id 10 and type O by N
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 4 and type O by N
# Substitute atom of id 9 and type Br by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 11 and type N by O
# Substitute atom of id 8 and type O by N
# Substitute atom of id 5 and type O by F
# Substitute atom of id 5 and type O by Br
# Substitute atom of id 8 and type O by N
# Substitute atom of id 8 and type N by O
# Substitute atom of id 5 and type O by N
# Substitute atom of id 5 and type N by F
# Substitute atom of id 5 and type O by Br
# Substitute atom of id 11 and type O by N
# Substitute atom of id 8 and type O by N
# Substitute atom of id 5 and type O by Br
# Substitute atom of id 7 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 4 and type N by Br
# Substitute atom of id 4 and type N by F
# Substitute atom of id 4 and type N by Br
# Substitute atom of id 11 and type O by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 7 and type O by N
# Substitute atom of id 10 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 10 and type O by F
# Substitute atom of id 12 and type F by N
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 10 and type O by F
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 10 and type O by N
# Substitute atom of id 7 and type N by Br
# Substitute atom of id 7 and type Br by N
# Substitute atom of id 5 and type Br by N
# Substitute atom of id 5 and type N by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 7 and type N by F
# Substitute atom of id 5 and type Br by O
# Substitute atom of id 1 and type N by O
# Substitute atom of id 12 and type F by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 10 and type F by N
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 10 and type F by N
# Substitute atom of id 10 and type F by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 8 and type O by N
# Substitute atom of id 8 and type O by N
# Substitute atom of id 11 and type Br by N
# Substitute atom of id 11 and type N by Br
# Substitute atom of id 5 and type Br by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 9 and type Br by F
# Substitute atom of id 5 and type F by O
# Substitute atom of id 5 and type O by F
# Substitute atom of id 11 and type O by N
# Substitute atom of id 5 and type F by N
# Substitute atom of id 5 and type N by Br
# Substitute atom of id 7 and type N by F
# Substitute atom of id 5 and type Br by F
# Substitute atom of id 5 and type Br by O
# Substitute atom of id 5 and type O by Br
# Substitute atom of id 5 and type Br by N
# Substitute atom of id 5 and type N by F
# Substitute atom of id 7 and type N by Br
# Substitute atom of id 7 and type N by Br
# Substitute atom of id 12 and type N by O
# Substitute atom of id 12 and type N by O
# Substitute atom of id 6 and type O by N
# Substitute atom of id 6 and type O by N
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 9 and type N by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 9 and type Br by O
# Substitute atom of id 7 and type O by F
# Substitute atom of id 7 and type F by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 7 and type Br by F
# Substitute atom of id 12 and type N by O
# Substitute atom of id 7 and type Br by F
# Substitute atom of id 12 and type N by F
# Substitute atom of id 7 and type Br by N
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 9 and type O by Br
# Substitute atom of id 9 and type O by N
# Substitute atom of id 5 and type F by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 0 and type Br by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type N by F
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 5 and type F by O
# Substitute atom of id 12 and type N by O
# Substitute atom of id 10 and type O by N
# Substitute atom of id 8 and type O by N
# Substitute atom of id 8 and type N by Br
# Substitute atom of id 8 and type O by F
# Substitute atom of id 10 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 10 and type O by F
# Substitute atom of id 0 and type O by F
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 5 and type Br by O
# Substitute atom of id 5 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 5 and type F by N
# Substitute atom of id 11 and type N by F
# Substitute atom of id 5 and type F by O
# Substitute atom of id 6 and type N by O
# Substitute atom of id 6 and type N by O
# Substitute atom of id 6 and type O by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 12 and type F by Br
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 10 and type O by F
# Substitute atom of id 3 and type N by O
# Substitute atom of id 12 and type N by F
# Substitute atom of id 9 and type F by N
# Substitute atom of id 12 and type N by F
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 12 and type N by O
# Substitute atom of id 11 and type N by F
# Substitute atom of id 5 and type N by O
# Substitute atom of id 3 and type N by F
# Substitute atom of id 5 and type N by O
# Substitute atom of id 3 and type N by O
# Substitute atom of id 11 and type N by O
# Substitute atom of id 11 and type O by F
# Substitute atom of id 12 and type F by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type F by N
# Substitute atom of id 3 and type N by O
# Substitute atom of id 11 and type N by O
# Substitute atom of id 9 and type F by O
# Substitute atom of id 11 and type Br by N
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 11 and type Br by N
# Substitute atom of id 11 and type N by O
# Substitute atom of id 9 and type F by N
# Substitute atom of id 4 and type Br by F
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 7 and type Br by F
# Substitute atom of id 12 and type O by N
# Substitute atom of id 7 and type O by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 10 and type O by F
# Substitute atom of id 5 and type N by F
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 5 and type N by Br
# Substitute atom of id 5 and type Br by O
# Substitute atom of id 2 and type N by O
# Substitute atom of id 2 and type O by N
# Substitute atom of id 9 and type F by N
# Substitute atom of id 11 and type Br by N
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 9 and type F by O
# Substitute atom of id 9 and type N by F
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 11 and type O by N
# Substitute atom of id 9 and type N by O
# Substitute atom of id 11 and type N by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 11 and type N by O
# Substitute atom of id 8 and type N by F
# Substitute atom of id 7 and type N by Br
# Substitute atom of id 7 and type Br by N
# Substitute atom of id 8 and type N by O
# Substitute atom of id 12 and type F by N
# Substitute atom of id 12 and type F by N
# Substitute atom of id 10 and type O by N
# Substitute atom of id 3 and type F by O
# Substitute atom of id 10 and type O by N
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 3 and type N by F
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 3 and type N by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 9 and type O by F
# Substitute atom of id 11 and type N by Br
# Substitute atom of id 9 and type O by N
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 9 and type O by F
# Substitute atom of id 3 and type O by F
# Substitute atom of id 3 and type F by N
# Substitute atom of id 10 and type N by F
# Substitute atom of id 10 and type N by O
# Substitute atom of id 10 and type N by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 10 and type O by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 11 and type N by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 7 and type N by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 8 and type O by Br
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 0 and type Br by F
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 0 and type O by N
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 0 and type O by N
# Substitute atom of id 9 and type O by Br
# Substitute atom of id 9 and type Br by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 11 and type N by F
# Substitute atom of id 0 and type N by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 9 and type O by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 10 and type N by O
# Substitute atom of id 6 and type N by O
# Substitute atom of id 6 and type O by F
# Substitute atom of id 8 and type O by N
# Substitute atom of id 5 and type N by O
# Substitute atom of id 6 and type N by Br
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 9 and type N by O
# Substitute atom of id 11 and type F by N
# Substitute atom of id 9 and type N by F
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 10 and type O by F
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 10 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 7 and type N by O
# Substitute atom of id 7 and type O by F
# Substitute atom of id 0 and type N by O
# Substitute atom of id 0 and type O by N
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 9 and type N by O
# Substitute atom of id 11 and type F by N
# Substitute atom of id 11 and type F by O
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 11 and type F by N
# Substitute atom of id 11 and type N by O
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 10 and type N by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 0 and type N by O
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 8 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 6 and type O by N
# Substitute atom of id 9 and type Br by O
# Substitute atom of id 9 and type Br by N
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 10 and type N by O
# Substitute atom of id 10 and type Br by F
# Substitute atom of id 10 and type F by Br
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 12 and type N by O
# Substitute atom of id 7 and type N by F
# Substitute atom of id 12 and type N by O
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 8 and type N by O
# Substitute atom of id 4 and type Br by N
# Substitute atom of id 4 and type N by F
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 4 and type Br by N
# Substitute atom of id 5 and type N by O
# Substitute atom of id 4 and type Br by F
# Substitute atom of id 10 and type O by F
# Substitute atom of id 10 and type F by Br
# Substitute atom of id 12 and type N by O
# Substitute atom of id 7 and type N by O
# Substitute atom of id 10 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 5 and type O by N
# Substitute atom of id 1 and type N by O
# Substitute atom of id 5 and type O by F
# Substitute atom of id 5 and type O by Br
# Substitute atom of id 5 and type Br by F
# Substitute atom of id 3 and type O by N
# Substitute atom of id 6 and type N by O
# Substitute atom of id 6 and type O by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 0 and type O by N
# Substitute atom of id 6 and type N by F
# Substitute atom of id 11 and type N by Br
# Substitute atom of id 6 and type N by O
# Substitute atom of id 4 and type O by N
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 3 and type O by Br
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 3 and type O by F
# Substitute atom of id 2 and type Br by F
# Substitute atom of id 2 and type Br by F
# Substitute atom of id 2 and type Br by N
# Substitute atom of id 0 and type F by N
# Substitute atom of id 5 and type N by O
# Substitute atom of id 2 and type O by N
# Substitute atom of id 2 and type O by N
# Substitute atom of id 11 and type O by F
# Substitute atom of id 0 and type F by N
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 0 and type Br by F
# Substitute atom of id 2 and type Br by N
# Substitute atom of id 2 and type N by Br
# Substitute atom of id 5 and type N by O
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 0 and type F by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 2 and type Br by N
# Substitute atom of id 0 and type F by O
# Substitute atom of id 2 and type Br by N
# Substitute atom of id 0 and type O by N
# Substitute atom of id 2 and type Br by O
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 2 and type Br by F
# Substitute atom of id 0 and type F by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 2 and type Br by F
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 9 and type O by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 2 and type N by O
# Substitute atom of id 3 and type O by N
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 2 and type N by O
# Substitute atom of id 2 and type N by O
# Substitute atom of id 2 and type O by N
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 2 and type Br by O
# Substitute atom of id 2 and type Br by F
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 0 and type F by O
# Substitute atom of id 2 and type Br by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 2 and type Br by O
# Substitute atom of id 0 and type F by O
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 4 and type N by O
# Substitute atom of id 10 and type N by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 8 and type Br by N
# Substitute atom of id 9 and type N by O
# Substitute atom of id 11 and type N by O
# Substitute atom of id 3 and type N by O
# Substitute atom of id 11 and type N by O
# Substitute atom of id 3 and type N by O
# Substitute atom of id 11 and type N by O
# Substitute atom of id 5 and type N by F
# Substitute atom of id 5 and type F by N
# Substitute atom of id 5 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 12 and type N by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 11 and type O by F
# Substitute atom of id 0 and type F by O
# Substitute atom of id 0 and type O by F
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 9 and type O by Br
# Substitute atom of id 0 and type F by O
# Substitute atom of id 0 and type F by O
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 11 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 3 and type N by F
# Substitute atom of id 9 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 11 and type N by Br
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 6 and type O by Br
# Substitute atom of id 12 and type N by F
# Substitute atom of id 12 and type F by Br
# Substitute atom of id 12 and type N by F
# Substitute atom of id 12 and type N by O

# %% [markdown]
# Population after three steps

# %%
pop = logger.populations[3]
novel = pop_minus(pop, test_pop)
mols = [member.rdkit_mol for member in novel.members]
Draw.MolsToGridImage(mols, molsPerRow=4)

# %% [markdown]
# Population after one step

# %%
pop = logger.populations[1]
novel = pop_minus(pop, test_pop)
mols = [member.rdkit_mol for member in novel.members]
Draw.MolsToGridImage(mols, molsPerRow=4)

# %% [markdown]
# After many steps

# %%
pop = logger.populations[-1]
novel = pop_minus(pop, test_pop)
mols = [member.rdkit_mol for member in novel.members]
Draw.MolsToGridImage(mols, molsPerRow=4)

# %% [markdown]
# ### Load ambigols

# %%
import pandas as pd

# %%
ambigol_data = pd.read_csv("ambigols.csv")
ambigol_data.head()
# Out:
#                                               Smiles  is_susceptible       mic
# 0  OC1=C(OC2=CC=C(Cl)C=C2Cl)C(Cl)=CC(Cl)=C1C3=C(O...            True  0.570000
# 1  OC1=C(OC2=CC=C(Cl)C=C2Cl)C(Cl)=CC(Cl)=C1OC3=C(...            True  0.160000
# 2  ClC1=C(O)C(Cl)=C(OC2=C(Cl)C=C(Cl)C=C2)C=C1OC3=...            True  1.956667
# 3  ClC1=CC(Cl)=C(O)C(C2=C(Cl)C(OC3=C(Cl)C=C(Cl)C=...            True  0.653333
# 4  ClC1=CC(Cl)=C(O)C(C2=C(OC3=C(Cl)C=C(Cl)C=C3)C(...            True  0.653333

# %%
ambigol_mols = [Chem.MolFromSmiles(smiles) for smiles in ambigol_data["Smiles"]]

# %%
test_pop = Population([PopMember(smiles) for smiles in ambigol_data["Smiles"]])

# %%
logger = Logger()
run_ga(test_pop, SubstitutionMovingOnlyActionSpace, 30, logger)
# Out:
# Substitute atom of id 4 and type O by N
# Substitute atom of id 0 and type Cl by N
# Substitute atom of id 14 and type Cl by O
# Substitute atom of id 0 and type Cl by Br
# Substitute atom of id 11 and type Cl by F
# Substitute atom of id 14 and type Cl by N
# Substitute atom of id 4 and type Cl by F
# Substitute atom of id 0 and type Cl by F
# Substitute atom of id 13 and type Cl by Br
# Substitute atom of id 3 and type O by N
# Substitute atom of id 13 and type Cl by N
# Substitute atom of id 11 and type Cl by Br
# Substitute atom of id 3 and type O by N
# Substitute atom of id 13 and type Cl by Br
# Substitute atom of id 8 and type Cl by F
# Substitute atom of id 0 and type Cl by O
# Substitute atom of id 7 and type Cl by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 13 and type Cl by F
# Substitute atom of id 16 and type O by Br
# Substitute atom of id 16 and type O by F
# Substitute atom of id 0 and type Cl by F
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 9 and type O by Br
# Substitute atom of id 12 and type Cl by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 4 and type Cl by O
# Substitute atom of id 0 and type Cl by O
# Substitute atom of id 0 and type Cl by O
# Substitute atom of id 12 and type Cl by O
# Substitute atom of id 12 and type Cl by F
# Substitute atom of id 12 and type F by O
# Substitute atom of id 5 and type Cl by F
# Substitute atom of id 23 and type Cl by F
# Substitute atom of id 23 and type Cl by O
# Substitute atom of id 4 and type Cl by N
# Substitute atom of id 0 and type Cl by F
# Substitute atom of id 11 and type Cl by F
# Substitute atom of id 17 and type O by F
# Substitute atom of id 17 and type O by F
# Substitute atom of id 7 and type Cl by F
# Substitute atom of id 13 and type Cl by N
# Substitute atom of id 7 and type Cl by O
# Substitute atom of id 10 and type Cl by N
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 12 and type Cl by F
# Substitute atom of id 12 and type Cl by N
# Substitute atom of id 17 and type O by F
# Substitute atom of id 4 and type Cl by F
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 17 and type O by F
# Substitute atom of id 12 and type Cl by N
# Substitute atom of id 4 and type Cl by O
# Substitute atom of id 11 and type Cl by N
# Substitute atom of id 5 and type Cl by O
# Substitute atom of id 5 and type O by N
# Substitute atom of id 24 and type O by Br
# Substitute atom of id 9 and type Cl by O
# Substitute atom of id 7 and type Cl by O
# Substitute atom of id 26 and type Cl by F
# Substitute atom of id 9 and type Cl by Br
# Substitute atom of id 15 and type Br by F
# Substitute atom of id 12 and type Cl by Br
# Substitute atom of id 4 and type Cl by Br
# Substitute atom of id 17 and type O by N
# Substitute atom of id 9 and type Cl by Br
# Substitute atom of id 12 and type Cl by F
# Substitute atom of id 15 and type Br by O
# Substitute atom of id 5 and type N by Br
# Substitute atom of id 12 and type Cl by Br
# Substitute atom of id 5 and type N by F
# Substitute atom of id 17 and type Cl by O
# Substitute atom of id 5 and type N by F
# Substitute atom of id 12 and type Cl by Br
# Substitute atom of id 15 and type Br by F
# Substitute atom of id 5 and type N by O
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 17 and type F by O
# Substitute atom of id 12 and type Cl by N
# Substitute atom of id 3 and type F by Br
# Substitute atom of id 6 and type Cl by O
# Substitute atom of id 6 and type O by F
# Substitute atom of id 0 and type O by N
# Substitute atom of id 0 and type O by N
# Substitute atom of id 1 and type O by N
# Substitute atom of id 15 and type Br by F
# Substitute atom of id 15 and type Br by F
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 17 and type Cl by N
# Substitute atom of id 17 and type N by O
# Substitute atom of id 16 and type O by Br
# Substitute atom of id 8 and type Cl by O
# Substitute atom of id 12 and type Cl by F
# Substitute atom of id 10 and type Cl by F
# Substitute atom of id 8 and type Cl by N
# Substitute atom of id 7 and type Cl by N
# Substitute atom of id 7 and type Cl by N
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 18 and type Cl by Br
# Substitute atom of id 18 and type Cl by N
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 7 and type Cl by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 13 and type F by Br
# Substitute atom of id 1 and type N by Br
# Substitute atom of id 7 and type Cl by Br
# Substitute atom of id 0 and type F by O
# Substitute atom of id 17 and type Cl by Br
# Substitute atom of id 7 and type Cl by F
# Substitute atom of id 9 and type N by O
# Substitute atom of id 12 and type Cl by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 17 and type F by O
# Substitute atom of id 16 and type N by O
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 17 and type F by O
# Substitute atom of id 17 and type F by N
# Substitute atom of id 17 and type F by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 15 and type Cl by F
# Substitute atom of id 12 and type Cl by F
# Substitute atom of id 15 and type Cl by Br
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 6 and type N by O
# Substitute atom of id 12 and type Cl by F
# Substitute atom of id 10 and type Cl by F
# Substitute atom of id 7 and type F by Br
# Substitute atom of id 7 and type F by O
# Substitute atom of id 17 and type Cl by N
# Substitute atom of id 7 and type F by N
# Substitute atom of id 9 and type N by O
# Substitute atom of id 12 and type Cl by F
# Substitute atom of id 15 and type Cl by Br
# Substitute atom of id 14 and type N by O
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 14 and type N by F
# Substitute atom of id 9 and type N by O
# Substitute atom of id 11 and type Cl by O
# Substitute atom of id 16 and type O by N
# Substitute atom of id 16 and type N by F
# Substitute atom of id 5 and type Cl by F
# Substitute atom of id 17 and type F by Br
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 14 and type N by F
# Substitute atom of id 8 and type F by O
# Substitute atom of id 15 and type N by Br
# Substitute atom of id 1 and type O by N
# Substitute atom of id 5 and type N by Br
# Substitute atom of id 5 and type N by O
# Substitute atom of id 15 and type N by O
# Substitute atom of id 18 and type Cl by F
# Substitute atom of id 1 and type O by N
# Substitute atom of id 9 and type Cl by F
# Substitute atom of id 15 and type Cl by F
# Substitute atom of id 0 and type F by N
# Substitute atom of id 15 and type Cl by N
# Substitute atom of id 15 and type N by F
# Substitute atom of id 15 and type Cl by N
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 14 and type O by Br
# Substitute atom of id 5 and type Cl by N
# Substitute atom of id 8 and type Cl by F
# Substitute atom of id 8 and type F by N
# Substitute atom of id 17 and type Br by F
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 17 and type Cl by N
# Substitute atom of id 17 and type Cl by Br
# Substitute atom of id 7 and type N by F
# Substitute atom of id 13 and type N by O
# Substitute atom of id 13 and type N by F
# Substitute atom of id 13 and type F by O
# Substitute atom of id 18 and type F by O
# Substitute atom of id 1 and type O by N
# Substitute atom of id 7 and type Cl by F
# Substitute atom of id 5 and type N by Br
# Substitute atom of id 5 and type N by O
# Substitute atom of id 5 and type N by F
# Substitute atom of id 5 and type F by O
# Substitute atom of id 0 and type N by F
# Substitute atom of id 0 and type N by O
# Substitute atom of id 4 and type Cl by N
# Substitute atom of id 13 and type O by Br
# Substitute atom of id 0 and type F by O
# Substitute atom of id 5 and type Cl by N
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 5 and type Cl by O
# Substitute atom of id 18 and type F by N
# Substitute atom of id 1 and type O by N
# Substitute atom of id 13 and type Br by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 8 and type F by N
# Substitute atom of id 11 and type Cl by N
# Substitute atom of id 16 and type Br by N
# Substitute atom of id 11 and type Cl by Br
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 14 and type Br by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 0 and type O by F
# Substitute atom of id 7 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 13 and type N by F
# Substitute atom of id 17 and type N by Br
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type F by O
# Substitute atom of id 5 and type N by F
# Substitute atom of id 0 and type N by O
# Substitute atom of id 11 and type F by N
# Substitute atom of id 11 and type F by O
# Substitute atom of id 16 and type N by O
# Substitute atom of id 15 and type N by O
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 17 and type Cl by Br
# Substitute atom of id 15 and type Br by F
# Substitute atom of id 5 and type O by F
# Substitute atom of id 5 and type O by N
# Substitute atom of id 16 and type F by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 16 and type F by O
# Substitute atom of id 7 and type F by Br
# Substitute atom of id 10 and type N by F
# Substitute atom of id 1 and type O by N
# Substitute atom of id 5 and type N by Br
# Substitute atom of id 15 and type N by O
# Substitute atom of id 16 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 9 and type O by N
# Substitute atom of id 3 and type Br by N
# Substitute atom of id 14 and type O by F
# Substitute atom of id 9 and type O by N
# Substitute atom of id 12 and type Cl by O
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 1 and type O by N
# Substitute atom of id 15 and type N by O
# Substitute atom of id 9 and type Br by F
# Substitute atom of id 5 and type N by F
# Substitute atom of id 14 and type O by F
# Substitute atom of id 12 and type O by F
# Substitute atom of id 14 and type O by N
# Substitute atom of id 5 and type N by F
# Substitute atom of id 12 and type O by N
# Substitute atom of id 14 and type O by F
# Substitute atom of id 4 and type N by Br
# Substitute atom of id 14 and type N by O
# Substitute atom of id 13 and type N by O
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 14 and type N by F
# Substitute atom of id 14 and type F by O
# Substitute atom of id 11 and type Cl by F
# Substitute atom of id 4 and type O by F
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 11 and type Cl by N
# Substitute atom of id 17 and type N by Br
# Substitute atom of id 10 and type O by N
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 12 and type F by N
# Substitute atom of id 12 and type F by O
# Substitute atom of id 10 and type O by N
# Substitute atom of id 5 and type N by F
# Substitute atom of id 7 and type Br by O
# Substitute atom of id 17 and type O by N
# Substitute atom of id 13 and type Br by F
# Substitute atom of id 9 and type F by O
# Substitute atom of id 1 and type O by N
# Substitute atom of id 18 and type N by O
# Substitute atom of id 18 and type N by F
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 13 and type N by F
# Substitute atom of id 1 and type O by F
# Substitute atom of id 17 and type N by Br
# Substitute atom of id 8 and type N by F
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 5 and type O by N
# Substitute atom of id 11 and type N by O
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 0 and type N by O
# Substitute atom of id 11 and type N by F
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 9 and type N by O
# Substitute atom of id 17 and type O by F
# Substitute atom of id 15 and type N by O
# Substitute atom of id 15 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 17 and type Br by N
# Substitute atom of id 17 and type Br by F
# Substitute atom of id 1 and type O by Br
# Substitute atom of id 13 and type F by N
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 4 and type N by O
# Substitute atom of id 18 and type F by N
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 9 and type N by F
# Substitute atom of id 9 and type F by O
# Substitute atom of id 9 and type N by F
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 4 and type N by O
# Substitute atom of id 14 and type O by N
# Substitute atom of id 14 and type O by F
# Substitute atom of id 14 and type F by O
# Substitute atom of id 14 and type O by Br
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 12 and type F by Br
# Substitute atom of id 6 and type O by Br
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 9 and type N by O
# Substitute atom of id 10 and type N by O
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 18 and type O by N
# Substitute atom of id 18 and type O by F
# Substitute atom of id 15 and type O by F
# Substitute atom of id 18 and type O by N
# Substitute atom of id 1 and type N by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 16 and type O by F
# Substitute atom of id 16 and type O by Br
# Substitute atom of id 7 and type N by O
# Substitute atom of id 13 and type F by N
# Substitute atom of id 1 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 16 and type F by Br
# Substitute atom of id 16 and type F by N
# Substitute atom of id 16 and type F by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 16 and type F by Br
# Substitute atom of id 18 and type O by N
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 4 and type F by N
# Substitute atom of id 5 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 14 and type N by O
# Substitute atom of id 8 and type N by Br
# Substitute atom of id 14 and type F by O
# Substitute atom of id 13 and type N by F
# Substitute atom of id 14 and type F by N
# Substitute atom of id 14 and type F by O
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 14 and type N by F
# Substitute atom of id 14 and type N by O
# Substitute atom of id 4 and type O by Br
# Substitute atom of id 14 and type O by N
# Substitute atom of id 11 and type F by O
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 16 and type O by N
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 17 and type O by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 18 and type N by F
# Substitute atom of id 10 and type O by N
# Substitute atom of id 18 and type N by F
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 15 and type N by F
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 6 and type N by Br
# Substitute atom of id 1 and type O by N
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 6 and type N by O
# Substitute atom of id 6 and type O by F
# Substitute atom of id 13 and type N by F
# Substitute atom of id 18 and type N by O
# Substitute atom of id 5 and type Br by F
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 11 and type O by F
# Substitute atom of id 18 and type O by N
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 1 and type N by O
# Substitute atom of id 13 and type N by O
# Substitute atom of id 5 and type N by O
# Substitute atom of id 18 and type N by O
# Substitute atom of id 5 and type O by N
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 13 and type N by O
# Substitute atom of id 17 and type N by F
# Substitute atom of id 9 and type N by O
# Substitute atom of id 13 and type N by F
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 18 and type F by N
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 18 and type O by N
# Substitute atom of id 4 and type Br by N
# Substitute atom of id 5 and type N by Br
# Substitute atom of id 17 and type Br by F
# Substitute atom of id 16 and type N by O
# Substitute atom of id 17 and type Br by F
# Substitute atom of id 6 and type Br by O
# Substitute atom of id 5 and type N by O
# Substitute atom of id 6 and type Br by F
# Substitute atom of id 13 and type Br by N
# Substitute atom of id 7 and type N by F
# Substitute atom of id 14 and type N by F
# Substitute atom of id 14 and type N by Br
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 5 and type N by O
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 5 and type N by F
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 16 and type N by F
# Substitute atom of id 4 and type O by N
# Substitute atom of id 4 and type O by Br
# Substitute atom of id 14 and type Br by O
# Substitute atom of id 4 and type Br by N
# Substitute atom of id 2 and type O by N
# Substitute atom of id 2 and type O by N
# Substitute atom of id 16 and type N by O
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 15 and type O by N
# Substitute atom of id 5 and type O by N
# Substitute atom of id 18 and type O by F
# Substitute atom of id 13 and type N by F
# Substitute atom of id 13 and type F by N
# Substitute atom of id 14 and type Br by N
# Substitute atom of id 14 and type N by F
# Substitute atom of id 13 and type O by N
# Substitute atom of id 13 and type N by O
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 13 and type O by N
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 14 and type Br by N
# Substitute atom of id 14 and type N by O
# Substitute atom of id 17 and type N by O
# Substitute atom of id 17 and type O by N
# Substitute atom of id 13 and type O by N
# Substitute atom of id 14 and type Br by N
# Substitute atom of id 17 and type N by O
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 12 and type O by N
# Substitute atom of id 18 and type O by F
# Substitute atom of id 4 and type O by N
# Substitute atom of id 4 and type N by Br
# Substitute atom of id 14 and type Br by N
# Substitute atom of id 14 and type N by O
# Substitute atom of id 10 and type N by F
# Substitute atom of id 10 and type N by F
# Substitute atom of id 9 and type N by O
# Substitute atom of id 7 and type F by N
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 7 and type F by O
# Substitute atom of id 7 and type F by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 7 and type F by Br
# Substitute atom of id 7 and type Br by N
# Substitute atom of id 11 and type F by N
# Substitute atom of id 13 and type O by N
# Substitute atom of id 4 and type N by Br
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 10 and type O by N
# Substitute atom of id 8 and type Br by O
# Substitute atom of id 18 and type N by F
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 3 and type N by F
# Substitute atom of id 10 and type Br by F
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 6 and type N by O
# Substitute atom of id 7 and type N by O
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 15 and type F by Br
# Substitute atom of id 10 and type O by N
# Substitute atom of id 15 and type Br by O
# Substitute atom of id 15 and type O by Br
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 14 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 15 and type F by O
# Substitute atom of id 9 and type O by F
# Substitute atom of id 15 and type F by Br
# Substitute atom of id 9 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 9 and type O by Br
# Substitute atom of id 18 and type F by O
# Substitute atom of id 10 and type Br by F
# Substitute atom of id 10 and type Br by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 16 and type N by O
# Substitute atom of id 15 and type O by N
# Substitute atom of id 7 and type Br by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 4 and type O by N
# Substitute atom of id 6 and type N by O
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 10 and type Br by N
# Substitute atom of id 9 and type N by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 8 and type N by O
# Substitute atom of id 17 and type F by Br
# Substitute atom of id 8 and type N by O
# Substitute atom of id 5 and type O by F
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 15 and type O by F
# Substitute atom of id 17 and type F by N
# Substitute atom of id 17 and type F by O
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 10 and type N by O
# Substitute atom of id 17 and type N by Br
# Substitute atom of id 5 and type O by N
# Substitute atom of id 4 and type N by O
# Substitute atom of id 5 and type N by O
# Substitute atom of id 5 and type O by N
# Substitute atom of id 16 and type O by N
# Substitute atom of id 17 and type N by Br
# Substitute atom of id 13 and type N by F
# Substitute atom of id 8 and type N by O
# Substitute atom of id 10 and type O by F
# Substitute atom of id 10 and type O by N
# Substitute atom of id 10 and type N by Br
# Substitute atom of id 5 and type O by F
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 17 and type N by O
# Substitute atom of id 13 and type N by F
# Substitute atom of id 5 and type O by N
# Substitute atom of id 4 and type N by O
# Substitute atom of id 15 and type F by Br
# Substitute atom of id 2 and type Br by F
# Substitute atom of id 2 and type F by O
# Substitute atom of id 15 and type O by N
# Substitute atom of id 5 and type O by N
# Substitute atom of id 15 and type O by Br
# Substitute atom of id 0 and type N by F
# Substitute atom of id 5 and type O by Br
# Substitute atom of id 15 and type N by Br
# Substitute atom of id 13 and type F by Br
# Substitute atom of id 5 and type N by O
# Substitute atom of id 5 and type N by O
# Substitute atom of id 15 and type N by Br
# Substitute atom of id 5 and type F by O
# Substitute atom of id 9 and type N by O
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 5 and type Br by F
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 7 and type N by O
# Substitute atom of id 14 and type O by N
# Substitute atom of id 17 and type O by N
# Substitute atom of id 9 and type F by N
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 11 and type N by F
# Substitute atom of id 9 and type Br by F
# Substitute atom of id 11 and type N by F
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 15 and type O by F
# Substitute atom of id 16 and type Br by F
# Substitute atom of id 16 and type F by N
# Substitute atom of id 14 and type N by O
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 17 and type O by N
# Substitute atom of id 14 and type O by Br
# Substitute atom of id 13 and type O by N
# Substitute atom of id 0 and type O by F
# Substitute atom of id 15 and type O by F
# Substitute atom of id 11 and type Br by N
# Substitute atom of id 13 and type O by N
# Substitute atom of id 16 and type Br by O
# Substitute atom of id 0 and type O by F
# Substitute atom of id 9 and type F by N
# Substitute atom of id 11 and type N by F
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 11 and type N by O
# Substitute atom of id 11 and type O by F
# Substitute atom of id 0 and type O by N
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 15 and type Br by F
# Substitute atom of id 0 and type N by O
# Substitute atom of id 18 and type N by F
# Substitute atom of id 17 and type N by O
# Substitute atom of id 0 and type N by F
# Substitute atom of id 17 and type F by N
# Substitute atom of id 17 and type N by Br
# Substitute atom of id 7 and type O by F
# Substitute atom of id 11 and type N by O
# Substitute atom of id 17 and type F by N
# Substitute atom of id 14 and type F by O
# Substitute atom of id 14 and type O by N
# Substitute atom of id 16 and type N by O
# Substitute atom of id 14 and type F by O
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 14 and type O by F
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 3 and type O by N
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 13 and type O by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 2 and type F by Br
# Substitute atom of id 5 and type Br by F
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 16 and type N by O
# Substitute atom of id 16 and type N by O
# Substitute atom of id 5 and type Br by O
# Substitute atom of id 7 and type N by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 0 and type N by O
# Substitute atom of id 2 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 15 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 7 and type N by O
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 0 and type N by F
# Substitute atom of id 6 and type N by O
# Substitute atom of id 14 and type F by O
# Substitute atom of id 16 and type N by O
# Substitute atom of id 16 and type N by O
# Substitute atom of id 16 and type O by N
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 15 and type Br by O
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 5 and type O by N
# Substitute atom of id 18 and type F by O
# Substitute atom of id 18 and type O by F
# Substitute atom of id 16 and type N by O
# Substitute atom of id 16 and type O by N
# Substitute atom of id 7 and type O by N
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 17 and type O by N
# Substitute atom of id 13 and type N by F
# Substitute atom of id 14 and type F by Br
# Substitute atom of id 14 and type F by N
# Substitute atom of id 14 and type N by O
# Substitute atom of id 18 and type F by O
# Substitute atom of id 14 and type F by Br
# Substitute atom of id 17 and type Br by F
# Substitute atom of id 10 and type O by F
# Substitute atom of id 4 and type Br by O
# Substitute atom of id 14 and type O by N
# Substitute atom of id 4 and type Br by F
# Substitute atom of id 5 and type O by N
# Substitute atom of id 17 and type N by F
# Substitute atom of id 11 and type O by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 6 and type O by F
# Substitute atom of id 2 and type O by N
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 0 and type O by F
# Substitute atom of id 17 and type O by F
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 9 and type N by F
# Substitute atom of id 12 and type N by O
# Substitute atom of id 16 and type O by F
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 16 and type O by F
# Substitute atom of id 9 and type N by O
# Substitute atom of id 14 and type O by Br
# Substitute atom of id 12 and type N by F
# Substitute atom of id 17 and type N by O
# Substitute atom of id 6 and type O by N
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 0 and type Br by F
# Substitute atom of id 18 and type F by O
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 11 and type F by O
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 17 and type N by O
# Substitute atom of id 0 and type N by F
# Substitute atom of id 18 and type N by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 9 and type O by Br
# Substitute atom of id 14 and type O by F
# Substitute atom of id 6 and type O by N
# Substitute atom of id 6 and type N by O
# Substitute atom of id 6 and type O by N
# Substitute atom of id 6 and type O by N
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 13 and type N by F
# Substitute atom of id 13 and type F by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 1 and type O by N
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 1 and type O by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 18 and type O by F
# Substitute atom of id 14 and type O by F
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 18 and type O by F
# Substitute atom of id 12 and type N by O
# Substitute atom of id 4 and type O by F
# Substitute atom of id 10 and type F by O
# Substitute atom of id 4 and type O by Br
# Substitute atom of id 14 and type N by F
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 10 and type F by Br
# Substitute atom of id 18 and type O by F
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 4 and type O by N
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 16 and type O by N
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 14 and type F by N
# Substitute atom of id 14 and type N by Br
# Substitute atom of id 7 and type O by N
# Substitute atom of id 7 and type O by N
# Substitute atom of id 10 and type Br by F
# Substitute atom of id 0 and type F by N
# Substitute atom of id 18 and type F by O
# Substitute atom of id 0 and type F by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 8 and type N by O
# Substitute atom of id 8 and type O by N
# Substitute atom of id 8 and type N by Br
# Substitute atom of id 14 and type F by O
# Substitute atom of id 14 and type O by F
# Substitute atom of id 11 and type N by O
# Substitute atom of id 4 and type O by Br
# Substitute atom of id 0 and type N by F
# Substitute atom of id 15 and type O by Br
# Substitute atom of id 11 and type Br by N
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 15 and type O by N
# Substitute atom of id 11 and type N by O
# Substitute atom of id 11 and type N by Br
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 18 and type N by F
# Substitute atom of id 18 and type F by O
# Substitute atom of id 18 and type N by F
# Substitute atom of id 6 and type N by O
# Substitute atom of id 8 and type N by F
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 8 and type N by F
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 0 and type N by F
# Substitute atom of id 6 and type N by O
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 7 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 18 and type O by N
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 13 and type F by O
# Substitute atom of id 11 and type N by F
# Substitute atom of id 0 and type N by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 18 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 13 and type Br by F
# Substitute atom of id 13 and type F by N
# Substitute atom of id 17 and type F by Br
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 7 and type Br by N
# Substitute atom of id 17 and type N by O
# Substitute atom of id 3 and type N by Br
# Substitute atom of id 3 and type N by O
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 0 and type N by O
# Substitute atom of id 3 and type O by F
# Substitute atom of id 6 and type F by O
# Substitute atom of id 18 and type F by N
# Substitute atom of id 17 and type F by O
# Substitute atom of id 7 and type N by O
# Substitute atom of id 17 and type F by N
# Substitute atom of id 13 and type Br by N
# Substitute atom of id 13 and type N by O
# Substitute atom of id 0 and type O by N
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 0 and type N by F
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 18 and type F by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 6 and type N by O
# Substitute atom of id 6 and type O by Br
# Substitute atom of id 13 and type Br by N
# Substitute atom of id 11 and type N by O
# Substitute atom of id 11 and type O by F
# Substitute atom of id 4 and type F by O
# Substitute atom of id 16 and type O by Br
# Substitute atom of id 11 and type O by F
# Substitute atom of id 14 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 6 and type N by O
# Substitute atom of id 18 and type O by N
# Substitute atom of id 18 and type N by O
# Substitute atom of id 8 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 5 and type N by Br
# Substitute atom of id 16 and type N by O
# Substitute atom of id 14 and type O by Br
# Substitute atom of id 14 and type Br by N
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 17 and type Br by N
# Substitute atom of id 8 and type Br by F
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 0 and type Br by N
# Substitute atom of id 3 and type Br by O
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 3 and type Br by F
# Substitute atom of id 9 and type N by F
# Substitute atom of id 9 and type F by O
# Substitute atom of id 18 and type N by F
# Substitute atom of id 4 and type N by O
# Substitute atom of id 4 and type N by Br
# Substitute atom of id 9 and type N by O
# Substitute atom of id 9 and type F by N
# Substitute atom of id 3 and type N by O
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 12 and type F by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 16 and type N by Br
# Substitute atom of id 6 and type Br by N
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 14 and type N by O
# Substitute atom of id 14 and type O by Br
# Substitute atom of id 14 and type O by N
# Substitute atom of id 4 and type F by O
# Substitute atom of id 14 and type O by N
# Substitute atom of id 4 and type F by N
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 16 and type F by O
# Substitute atom of id 14 and type O by N
# Substitute atom of id 18 and type F by O
# Substitute atom of id 18 and type F by O
# Substitute atom of id 14 and type O by F
# Substitute atom of id 16 and type F by O
# Substitute atom of id 4 and type Br by O
# Substitute atom of id 4 and type Br by O
# Substitute atom of id 4 and type Br by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 10 and type Br by F
# Substitute atom of id 10 and type F by O
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 9 and type N by O
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 15 and type N by O
# Substitute atom of id 12 and type F by O
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 3 and type O by Br
# Substitute atom of id 11 and type N by O
# Substitute atom of id 12 and type F by N
# Substitute atom of id 12 and type N by O
# Substitute atom of id 12 and type F by O
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 12 and type F by Br
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 3 and type O by Br
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 1 and type O by N
# Substitute atom of id 0 and type O by F
# Substitute atom of id 9 and type N by O
# Substitute atom of id 18 and type F by O
# Substitute atom of id 0 and type O by N
# Substitute atom of id 9 and type N by O
# Substitute atom of id 18 and type F by O
# Substitute atom of id 14 and type O by F
# Substitute atom of id 14 and type F by Br
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 9 and type Br by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 4 and type N by O
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 3 and type O by N
# Substitute atom of id 3 and type N by O
# Substitute atom of id 18 and type F by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 3 and type F by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 18 and type N by O
# Substitute atom of id 18 and type N by O
# Substitute atom of id 17 and type O by N
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 15 and type F by N
# Substitute atom of id 14 and type F by N
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 14 and type Br by O
# Substitute atom of id 17 and type O by N
# Substitute atom of id 1 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 1 and type O by N
# Substitute atom of id 13 and type N by O
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 8 and type N by Br
# Substitute atom of id 18 and type O by F
# Substitute atom of id 18 and type F by O
# Substitute atom of id 0 and type N by F
# Substitute atom of id 14 and type O by N
# Substitute atom of id 12 and type F by N
# Substitute atom of id 14 and type O by N
# Substitute atom of id 18 and type N by F
# Substitute atom of id 3 and type Br by F
# Substitute atom of id 18 and type N by F
# Substitute atom of id 3 and type F by O
# Substitute atom of id 6 and type O by N
# Substitute atom of id 15 and type Br by O
# Substitute atom of id 0 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 18 and type O by N
# Substitute atom of id 18 and type O by F
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 16 and type O by F
# Substitute atom of id 18 and type F by N
# Substitute atom of id 8 and type N by O
# Substitute atom of id 18 and type F by N
# Substitute atom of id 1 and type O by N
# Substitute atom of id 11 and type Br by N
# Substitute atom of id 8 and type O by F
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 3 and type O by N
# Substitute atom of id 3 and type Br by F
# Substitute atom of id 3 and type F by N
# Substitute atom of id 8 and type N by O
# Substitute atom of id 13 and type N by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 7 and type O by F
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 0 and type Br by F
# Substitute atom of id 7 and type O by N
# Substitute atom of id 13 and type Br by O
# Substitute atom of id 0 and type N by F
# Substitute atom of id 13 and type Br by F
# Substitute atom of id 11 and type O by N
# Substitute atom of id 3 and type O by Br
# Substitute atom of id 12 and type F by N
# Substitute atom of id 18 and type F by N
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 12 and type F by N
# Substitute atom of id 3 and type O by Br
# Substitute atom of id 15 and type N by Br
# Substitute atom of id 15 and type N by O
# Substitute atom of id 17 and type F by N
# Substitute atom of id 15 and type O by F
# Substitute atom of id 15 and type F by Br
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 4 and type O by Br
# Substitute atom of id 4 and type Br by O
# Substitute atom of id 9 and type N by F
# Substitute atom of id 14 and type N by O
# Substitute atom of id 14 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 14 and type N by Br
# Substitute atom of id 3 and type F by Br
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 13 and type O by N
# Substitute atom of id 18 and type F by N
# Substitute atom of id 4 and type Br by O
# Substitute atom of id 12 and type F by Br
# Substitute atom of id 4 and type Br by F
# Substitute atom of id 15 and type N by F
# Substitute atom of id 12 and type F by N
# Substitute atom of id 18 and type F by O
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 12 and type F by Br
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 11 and type O by N
# Substitute atom of id 18 and type F by N
# Substitute atom of id 18 and type F by N
# Substitute atom of id 15 and type N by F
# Substitute atom of id 18 and type F by N
# Substitute atom of id 15 and type N by O
# Substitute atom of id 4 and type O by F
# Substitute atom of id 0 and type N by O
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 4 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 9 and type N by Br
# Substitute atom of id 13 and type O by Br
# Substitute atom of id 16 and type N by F
# Substitute atom of id 10 and type F by O
# Substitute atom of id 18 and type N by O
# Substitute atom of id 13 and type O by F
# Substitute atom of id 9 and type N by F
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 0 and type Br by F
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 17 and type N by F
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 7 and type N by O
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 13 and type O by Br
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 7 and type N by F
# Substitute atom of id 13 and type O by Br
# Substitute atom of id 15 and type O by F
# Substitute atom of id 15 and type F by O
# Substitute atom of id 15 and type O by Br
# Substitute atom of id 13 and type O by N
# Substitute atom of id 15 and type O by N
# Substitute atom of id 17 and type O by N
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 17 and type Br by N
# Substitute atom of id 12 and type O by F
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 9 and type F by O
# Substitute atom of id 6 and type O by Br
# Substitute atom of id 14 and type O by Br
# Substitute atom of id 14 and type O by N
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 15 and type O by F
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 18 and type Br by N
# Substitute atom of id 7 and type O by F
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 6 and type N by Br
# Substitute atom of id 17 and type O by F
# Substitute atom of id 15 and type N by F
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 15 and type F by Br
# Substitute atom of id 14 and type O by N
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 15 and type O by N
# Substitute atom of id 14 and type N by Br
# Substitute atom of id 17 and type F by O
# Substitute atom of id 16 and type N by O
# Substitute atom of id 17 and type F by N
# Substitute atom of id 8 and type Br by O
# Substitute atom of id 14 and type Br by F
# Substitute atom of id 14 and type Br by F
# Substitute atom of id 0 and type O by F
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 0 and type N by O
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 7 and type F by Br
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 17 and type N by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 5 and type F by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 17 and type Br by N
# Substitute atom of id 7 and type F by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 15 and type N by Br
# Substitute atom of id 7 and type F by N
# Substitute atom of id 17 and type Br by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 17 and type N by O
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 15 and type N by Br
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 0 and type N by F
# Substitute atom of id 15 and type N by Br
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 17 and type F by O
# Substitute atom of id 4 and type Br by F
# Substitute atom of id 17 and type F by N
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 12 and type O by N
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 0 and type N by O
# Substitute atom of id 0 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 7 and type F by O
# Substitute atom of id 12 and type O by N
# Substitute atom of id 5 and type N by O
# Substitute atom of id 18 and type F by O
# Substitute atom of id 3 and type Br by O
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 18 and type F by O
# Substitute atom of id 10 and type F by Br
# Substitute atom of id 1 and type O by N
# Substitute atom of id 4 and type Br by F
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 15 and type O by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 15 and type O by Br
# Substitute atom of id 3 and type Br by F
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 15 and type N by O
# Substitute atom of id 7 and type Br by F
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 8 and type N by O
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 16 and type Br by F
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 12 and type F by O
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 10 and type F by O
# Substitute atom of id 6 and type O by Br
# Substitute atom of id 18 and type N by Br
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 18 and type N by F
# Substitute atom of id 4 and type F by O
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 0 and type N by O
# Substitute atom of id 0 and type O by N
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 12 and type O by F
# Substitute atom of id 15 and type N by O
# Substitute atom of id 12 and type O by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 15 and type N by O
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 6 and type O by F
# Substitute atom of id 18 and type N by F
# Substitute atom of id 6 and type O by F
# Substitute atom of id 10 and type F by O
# Substitute atom of id 18 and type O by N
# Substitute atom of id 1 and type N by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 2 and type Br by F
# Substitute atom of id 2 and type F by N
# Substitute atom of id 0 and type F by Br
# Substitute atom of id 16 and type Br by O
# Substitute atom of id 15 and type N by O
# Substitute atom of id 0 and type F by O
# Substitute atom of id 8 and type Br by O
# Substitute atom of id 13 and type O by Br
# Substitute atom of id 14 and type F by Br
# Substitute atom of id 16 and type F by O
# Substitute atom of id 14 and type F by Br
# Substitute atom of id 16 and type Br by F
# Substitute atom of id 14 and type O by F
# Substitute atom of id 8 and type Br by O
# Substitute atom of id 16 and type Br by F
# Substitute atom of id 1 and type N by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 9 and type N by O
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 0 and type N by F
# Substitute atom of id 11 and type Br by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 7 and type O by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 14 and type O by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 7 and type F by Br
# Substitute atom of id 13 and type O by F
# Substitute atom of id 13 and type F by N
# Substitute atom of id 7 and type F by O
# Substitute atom of id 16 and type Br by O
# Substitute atom of id 8 and type Br by F
# Substitute atom of id 13 and type O by N
# Substitute atom of id 8 and type Br by O
# Substitute atom of id 18 and type F by N
# Substitute atom of id 7 and type O by N
# Substitute atom of id 2 and type O by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 11 and type O by Br
# Substitute atom of id 9 and type N by O
# Substitute atom of id 7 and type O by N
# Substitute atom of id 15 and type Br by F
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 15 and type F by O
# Substitute atom of id 1 and type O by N
# Substitute atom of id 1 and type N by O
# Substitute atom of id 1 and type O by N
# Substitute atom of id 15 and type N by Br
# Substitute atom of id 12 and type O by F
# Substitute atom of id 15 and type N by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 0 and type N by O
# Substitute atom of id 0 and type N by F
# Substitute atom of id 18 and type F by O
# Substitute atom of id 6 and type O by N
# Substitute atom of id 7 and type F by Br
# Substitute atom of id 1 and type N by O
# Substitute atom of id 5 and type O by N
# Substitute atom of id 0 and type O by N
# Substitute atom of id 2 and type N by O
# Substitute atom of id 5 and type O by F
# Substitute atom of id 0 and type O by N
# Substitute atom of id 0 and type O by N
# Substitute atom of id 1 and type O by N
# Substitute atom of id 11 and type F by O
# Substitute atom of id 0 and type O by F
# Substitute atom of id 10 and type N by O
# Substitute atom of id 11 and type F by O
# Substitute atom of id 10 and type N by O
# Substitute atom of id 18 and type F by O
# Substitute atom of id 15 and type N by F
# Substitute atom of id 15 and type F by O
# Substitute atom of id 18 and type F by O
# Substitute atom of id 18 and type F by N
# Substitute atom of id 15 and type O by N
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 14 and type O by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 15 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 4 and type N by Br
# Substitute atom of id 1 and type N by O
# Substitute atom of id 10 and type F by Br
# Substitute atom of id 8 and type F by Br
# Substitute atom of id 8 and type Br by F
# Substitute atom of id 0 and type O by F
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 18 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 7 and type N by O
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 15 and type F by Br
# Substitute atom of id 7 and type N by Br
# Substitute atom of id 2 and type F by N
# Substitute atom of id 16 and type Br by O
# Substitute atom of id 16 and type O by Br
# Substitute atom of id 16 and type Br by O
# Substitute atom of id 11 and type F by O
# Substitute atom of id 11 and type F by N
# Substitute atom of id 13 and type N by F
# Substitute atom of id 16 and type O by F
# Substitute atom of id 16 and type F by Br
# Substitute atom of id 5 and type F by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 2 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 11 and type F by O
# Substitute atom of id 11 and type F by O
# Substitute atom of id 2 and type O by N
# Substitute atom of id 11 and type F by N
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 13 and type F by Br
# Substitute atom of id 1 and type N by O
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 13 and type Br by N
# Substitute atom of id 11 and type F by O
# Substitute atom of id 13 and type N by O
# Substitute atom of id 13 and type N by O
# Substitute atom of id 8 and type O by Br
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 13 and type N by O
# Substitute atom of id 18 and type F by N
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 16 and type O by Br
# Substitute atom of id 12 and type O by N
# Substitute atom of id 16 and type O by N
# Substitute atom of id 10 and type O by Br
# Substitute atom of id 10 and type O by F
# Substitute atom of id 14 and type N by O
# Substitute atom of id 16 and type F by O
# Substitute atom of id 8 and type O by N
# Substitute atom of id 14 and type N by F
# Substitute atom of id 17 and type O by N
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 7 and type N by O
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 18 and type F by N
# Substitute atom of id 0 and type N by O
# Substitute atom of id 7 and type N by Br
# Substitute atom of id 12 and type Br by N
# Substitute atom of id 12 and type N by Br
# Substitute atom of id 6 and type O by N
# Substitute atom of id 16 and type N by Br
# Substitute atom of id 16 and type Br by O
# Substitute atom of id 17 and type O by N
# Substitute atom of id 0 and type N by F
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 9 and type F by N
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 16 and type O by Br
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 16 and type O by N
# Substitute atom of id 1 and type N by O
# Substitute atom of id 12 and type Br by F
# Substitute atom of id 15 and type O by N
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 13 and type F by Br
# Substitute atom of id 2 and type F by Br
# Substitute atom of id 7 and type O by N
# Substitute atom of id 11 and type N by F
# Substitute atom of id 16 and type O by Br
# Substitute atom of id 2 and type F by N

# %%
pop = logger.populations[4]
compare, _, sims = compare_generated_to_reference(pop, ambigol_mols)
img = Draw.MolsToGridImage(compare, molsPerRow=2, legends=sims, returnPNG=True)
img

# %% [markdown]
# ### With complex actions that change the core

# %%
from evomol.ga.defined_action_spaces import ComplexActionSpace

# %%
logger = Logger()
run_ga(test_pop, ComplexActionSpace, 30, logger)
# Out:
# Substitute atom of id 0 and type Cl by Br
# Substitute atom of id 16 and type Cl by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 17 and type O by N
# Substitute atom of id 14 and type Cl by F
# Substitute atom of id 4 and type O by N
# Substitute atom of id 14 and type Cl by Br
# Substitute atom of id 11 and type Cl by Br
# Substitute atom of id 7 and type O by N
# Substitute atom of id 0 and type Cl by O
# Substitute atom of id 0 and type Cl by N
# Substitute atom of id 10 and type Cl by N
# Substitute atom of id 13 and type Cl by N
# Substitute atom of id 25 and type Cl by F
# Substitute atom of id 4 and type Cl by O
# Substitute atom of id 13 and type Cl by Br
# Substitute atom of id 25 and type Cl by N
# Substitute atom of id 25 and type N by Br
# Substitute atom of id 17 and type Cl by N
# Substitute atom of id 25 and type Cl by N
# Substitute atom of id 23 and type Cl by O
# Substitute atom of id 14 and type Cl by O
# Substitute atom of id 3 and type Cl by N
# Substitute atom of id 6 and type Cl by O
# Substitute atom of id 8 and type Cl by N
# Substitute atom of id 11 and type Cl by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 13 and type Cl by O
# Substitute atom of id 20 and type Cl by Br
# Substitute atom of id 22 and type Cl by N
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 21 and type Cl by Br
# Substitute atom of id 25 and type Cl by Br
# Substitute atom of id 0 and type O by N
# Substitute atom of id 18 and type Cl by N
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 10 and type Cl by Br
# Substitute atom of id 18 and type Cl by O
# Substitute atom of id 9 and type O by Br
# Substitute atom of id 9 and type O by F
# Substitute atom of id 13 and type O by F
# Substitute atom of id 12 and type Cl by O
# Substitute atom of id 25 and type Br by O
# Substitute atom of id 0 and type N by O
# Substitute atom of id 16 and type Cl by Br
# Substitute atom of id 6 and type Cl by F
# Substitute atom of id 11 and type Cl by N
# Substitute atom of id 5 and type Cl by N
# Substitute atom of id 1 and type O by N
# Substitute atom of id 4 and type Cl by N
# Substitute atom of id 17 and type O by N
# Substitute atom of id 19 and type Cl by N
# Substitute atom of id 6 and type Cl by F
# Substitute atom of id 9 and type Cl by N
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 17 and type Cl by N
# Substitute atom of id 25 and type Cl by O
# Substitute atom of id 0 and type O by Br
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 14 and type Br by N
# Substitute atom of id 7 and type Cl by Br
# Substitute atom of id 13 and type O by N
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 20 and type Cl by F
# Substitute atom of id 8 and type Cl by Br
# Substitute atom of id 0 and type O by F
# Substitute atom of id 5 and type Cl by Br
# Substitute atom of id 17 and type Cl by N
# Substitute atom of id 0 and type Cl by N
# Substitute atom of id 7 and type Cl by F
# Substitute atom of id 17 and type Cl by Br
# Substitute atom of id 10 and type O by N
# Substitute atom of id 9 and type Cl by Br
# Substitute atom of id 15 and type Cl by O
# Substitute atom of id 7 and type Br by F
# Substitute atom of id 13 and type Cl by N
# Substitute atom of id 1 and type N by O
# Substitute atom of id 0 and type Cl by N
# Substitute atom of id 23 and type Br by F
# Substitute atom of id 5 and type Cl by N
# Substitute atom of id 5 and type Cl by O
# Substitute atom of id 17 and type Cl by O
# Substitute atom of id 3 and type Cl by N
# Substitute atom of id 8 and type Cl by Br
# Substitute atom of id 16 and type Cl by O
# Substitute atom of id 14 and type Cl by Br
# Substitute atom of id 21 and type Cl by N
# Substitute atom of id 21 and type Cl by Br
# Substitute atom of id 12 and type Cl by F
# Substitute atom of id 21 and type Cl by O
# Substitute atom of id 13 and type Br by N
# Substitute atom of id 6 and type Cl by F
# Substitute atom of id 20 and type Cl by O
# Substitute atom of id 4 and type Cl by F
# Substitute atom of id 22 and type Cl by O
# Substitute atom of id 21 and type Cl by N
# Substitute atom of id 22 and type Cl by N
# Substitute atom of id 16 and type N by O
# Substitute atom of id 8 and type Cl by Br
# Substitute atom of id 16 and type Cl by Br
# Substitute atom of id 4 and type Br by O
# Substitute atom of id 0 and type Cl by N
# Substitute atom of id 22 and type Cl by N
# Substitute atom of id 8 and type Br by F
# Substitute atom of id 7 and type Cl by F
# Substitute atom of id 8 and type Cl by F
# Substitute atom of id 7 and type Cl by N
# Substitute atom of id 23 and type Cl by F
# Substitute atom of id 25 and type O by F
# Substitute atom of id 15 and type Cl by N
# Substitute atom of id 1 and type O by N
# Substitute atom of id 11 and type Cl by N
# Substitute atom of id 15 and type F by O
# Substitute atom of id 4 and type Cl by Br
# Substitute atom of id 4 and type Cl by O
# Substitute atom of id 14 and type Br by F
# Substitute atom of id 7 and type F by Br
# Substitute atom of id 27 and type Cl by N
# Substitute atom of id 23 and type Cl by Br
# Substitute atom of id 18 and type Cl by O
# Substitute atom of id 9 and type O by N
# Substitute atom of id 17 and type Cl by Br
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 15 and type Br by O
# Substitute atom of id 4 and type O by Br
# Substitute atom of id 15 and type Br by N
# Substitute atom of id 5 and type Cl by N
# Substitute atom of id 20 and type Cl by Br
# Substitute atom of id 11 and type Cl by N
# Substitute atom of id 2 and type O by N
# Substitute atom of id 6 and type F by O
# Substitute atom of id 21 and type Cl by Br
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 19 and type Cl by F
# Substitute atom of id 0 and type N by F
# Substitute atom of id 21 and type Cl by N
# Substitute atom of id 23 and type O by N
# Substitute atom of id 7 and type O by F
# Substitute atom of id 26 and type Cl by F
# Substitute atom of id 4 and type Cl by Br
# Substitute atom of id 11 and type N by F
# Substitute atom of id 6 and type Cl by Br
# Substitute atom of id 10 and type Cl by F
# Substitute atom of id 27 and type Br by O
# Substitute atom of id 7 and type F by O
# Substitute atom of id 2 and type Cl by Br
# Substitute atom of id 16 and type Cl by N
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 17 and type Br by N
# Substitute atom of id 4 and type O by N
# Substitute atom of id 20 and type Cl by N
# Substitute atom of id 26 and type Cl by O
# Substitute atom of id 20 and type Br by F
# Substitute atom of id 5 and type Cl by F
# Substitute atom of id 3 and type Cl by N
# Substitute atom of id 20 and type F by N
# Substitute atom of id 24 and type Cl by N
# Substitute atom of id 2 and type Cl by F
# Substitute atom of id 8 and type F by O
# Substitute atom of id 24 and type Cl by O
# Substitute atom of id 22 and type Cl by O
# Substitute atom of id 17 and type F by O
# Substitute atom of id 17 and type F by N
# Substitute atom of id 11 and type Cl by O
# Substitute atom of id 11 and type Cl by Br
# Substitute atom of id 24 and type Cl by F
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 3 and type Br by O
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 14 and type O by Br
# Substitute atom of id 23 and type Cl by O
# Substitute atom of id 23 and type Cl by N
# Substitute atom of id 6 and type Cl by F
# Substitute atom of id 16 and type Br by N
# Substitute atom of id 5 and type O by N
# Substitute atom of id 2 and type Br by N
# Substitute atom of id 20 and type Cl by N
# Substitute atom of id 20 and type Cl by N
# Substitute atom of id 23 and type Cl by N
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 12 and type N by O
# Substitute atom of id 17 and type N by Br
# Substitute atom of id 23 and type N by Br
# Substitute atom of id 4 and type O by N
# Substitute atom of id 17 and type Cl by O
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 15 and type O by N
# Substitute atom of id 21 and type Cl by Br
# Substitute atom of id 18 and type Cl by Br
# Substitute atom of id 19 and type Br by F
# Substitute atom of id 2 and type Br by O
# Substitute atom of id 15 and type O by F
# Substitute atom of id 15 and type O by Br
# Substitute atom of id 22 and type F by O
# Substitute atom of id 20 and type Cl by Br
# Substitute atom of id 13 and type Cl by F
# Substitute atom of id 25 and type F by Br
# Substitute atom of id 25 and type Br by F
# Substitute atom of id 20 and type F by O
# Substitute atom of id 24 and type O by F
# Substitute atom of id 9 and type F by O
# Substitute atom of id 16 and type N by Br
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 11 and type Cl by F
# Substitute atom of id 18 and type Br by O
# Substitute atom of id 11 and type Cl by Br
# Substitute atom of id 25 and type Cl by Br
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 22 and type O by F
# Substitute atom of id 16 and type N by F
# Substitute atom of id 2 and type Cl by N
# Substitute atom of id 12 and type Br by O
# Substitute atom of id 8 and type Cl by O
# Substitute atom of id 23 and type F by Br
# Substitute atom of id 2 and type N by O
# Substitute atom of id 24 and type O by N
# Substitute atom of id 20 and type N by F
# Substitute atom of id 19 and type N by O
# Substitute atom of id 9 and type F by O
# Substitute atom of id 15 and type F by N
# Substitute atom of id 7 and type O by Br
# Substitute atom of id 11 and type F by O
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 17 and type N by Br
# Substitute atom of id 19 and type N by O
# Substitute atom of id 23 and type O by F
# Substitute atom of id 18 and type Cl by O
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 14 and type N by F
# Substitute atom of id 13 and type Br by F
# Substitute atom of id 2 and type Cl by N
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 27 and type F by O
# Substitute atom of id 2 and type N by F
# Substitute atom of id 24 and type F by N
# Substitute atom of id 24 and type F by O
# Substitute atom of id 13 and type O by N
# Substitute atom of id 5 and type O by F
# Substitute atom of id 0 and type N by Br
# Substitute atom of id 14 and type F by O
# Substitute atom of id 8 and type F by N
# Substitute atom of id 11 and type Cl by N
# Substitute atom of id 19 and type F by N
# Substitute atom of id 8 and type F by O
# Substitute atom of id 11 and type Br by N
# Substitute atom of id 20 and type Cl by N
# Substitute atom of id 26 and type O by Br
# Substitute atom of id 22 and type F by Br
# Substitute atom of id 2 and type N by O
# Substitute atom of id 27 and type O by Br
# Substitute atom of id 22 and type F by O
# Substitute atom of id 19 and type O by Br
# Substitute atom of id 14 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 25 and type F by N
# Substitute atom of id 25 and type N by Br
# Substitute atom of id 17 and type N by F
# Substitute atom of id 13 and type N by F
# Substitute atom of id 8 and type N by O
# Substitute atom of id 24 and type O by N
# Substitute atom of id 14 and type N by Br
# Substitute atom of id 17 and type Cl by Br
# Substitute atom of id 6 and type Cl by N
# Substitute atom of id 23 and type Br by F
# Substitute atom of id 14 and type N by Br
# Substitute atom of id 9 and type O by N
# Substitute atom of id 14 and type Br by N
# Substitute atom of id 19 and type O by Br
# Substitute atom of id 17 and type Cl by Br
# Substitute atom of id 22 and type Cl by O
# Substitute atom of id 23 and type Cl by O
# Substitute atom of id 12 and type O by Br
# Substitute atom of id 23 and type Cl by F
# Substitute atom of id 6 and type Br by O
# Substitute atom of id 1 and type N by O
# Substitute atom of id 18 and type Cl by N
# Substitute atom of id 8 and type Cl by O
# Substitute atom of id 16 and type N by F
# Substitute atom of id 5 and type F by Br
# Substitute atom of id 5 and type Br by N
# Substitute atom of id 15 and type O by N
# Substitute atom of id 15 and type N by O
# Substitute atom of id 5 and type F by O
# Substitute atom of id 2 and type Cl by N
# Substitute atom of id 20 and type N by F
# Substitute atom of id 4 and type N by F
# Substitute atom of id 18 and type O by Br
# Substitute atom of id 13 and type N by Br
# Substitute atom of id 14 and type O by N
# Substitute atom of id 10 and type Cl by O
# Substitute atom of id 25 and type Br by O
# Substitute atom of id 7 and type Br by O
# Substitute atom of id 14 and type Br by N
# Substitute atom of id 4 and type N by F
# Substitute atom of id 3 and type O by N
# Substitute atom of id 19 and type N by Br
# Substitute atom of id 15 and type Cl by Br
# Substitute atom of id 12 and type F by N
# Substitute atom of id 6 and type O by F
# Substitute atom of id 6 and type O by F
# Substitute atom of id 18 and type F by O
# Substitute atom of id 11 and type O by N
# Substitute atom of id 17 and type F by O
# Substitute atom of id 15 and type N by O
# Substitute atom of id 11 and type N by O
# Substitute atom of id 22 and type Br by F
# Substitute atom of id 25 and type F by O
# Substitute atom of id 19 and type Cl by N
# Substitute atom of id 23 and type N by O
# Substitute atom of id 19 and type Cl by Br
# Substitute atom of id 18 and type O by F
# Substitute atom of id 18 and type F by Br
# Substitute atom of id 21 and type O by N
# Substitute atom of id 18 and type O by F
# Substitute atom of id 18 and type F by O
# Substitute atom of id 21 and type O by N
# Substitute atom of id 11 and type Cl by Br
# Substitute atom of id 11 and type Cl by O
# Substitute atom of id 9 and type Br by O
# Substitute atom of id 15 and type O by N
# Substitute atom of id 12 and type F by O
# Substitute atom of id 8 and type F by O
# Substitute atom of id 18 and type Br by F
# Substitute atom of id 19 and type Br by O
# Substitute atom of id 12 and type F by N
# Substitute atom of id 15 and type Cl by Br
# Substitute atom of id 8 and type F by Br
# Substitute atom of id 15 and type Cl by F
# Substitute atom of id 10 and type Br by F
# Substitute atom of id 17 and type Br by O
# Substitute atom of id 16 and type Br by F
# Substitute atom of id 26 and type N by F
# Substitute atom of id 11 and type O by N
# Substitute atom of id 20 and type Cl by N
# Substitute atom of id 15 and type O by N
# Substitute atom of id 19 and type Cl by O
# Substitute atom of id 20 and type Cl by F
# Substitute atom of id 11 and type O by N
# Substitute atom of id 14 and type N by O
# Substitute atom of id 5 and type Br by F
# Substitute atom of id 11 and type O by N
# Substitute atom of id 4 and type Br by F
# Substitute atom of id 15 and type Cl by F
# Substitute atom of id 15 and type Cl by N
# Substitute atom of id 23 and type Br by O
# Substitute atom of id 16 and type N by O
# Substitute atom of id 14 and type Br by O
# Substitute atom of id 17 and type O by F
# Substitute atom of id 11 and type Cl by O
# Substitute atom of id 24 and type Br by F
# Substitute atom of id 25 and type N by F
# Substitute atom of id 15 and type O by F
# Substitute atom of id 22 and type Br by N
# Substitute atom of id 21 and type Br by F
# Substitute atom of id 11 and type Br by F
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 19 and type O by Br
# Substitute atom of id 17 and type O by F
# Substitute atom of id 23 and type Br by F
# Substitute atom of id 4 and type Br by O
# Substitute atom of id 17 and type O by N
# Substitute atom of id 26 and type F by O
# Substitute atom of id 21 and type N by O
# Substitute atom of id 13 and type Br by N
# Substitute atom of id 20 and type O by N
# Substitute atom of id 5 and type Br by F
# Substitute atom of id 12 and type N by O
# Substitute atom of id 20 and type O by F
# Substitute atom of id 25 and type Br by O
# Substitute atom of id 18 and type O by F
# Substitute atom of id 20 and type O by F
# Substitute atom of id 5 and type Br by F
# Substitute atom of id 3 and type F by N
# Substitute atom of id 3 and type F by Br
# Substitute atom of id 3 and type F by N
# Substitute atom of id 3 and type N by O
# Substitute atom of id 9 and type F by N
# Substitute atom of id 11 and type O by N
# Substitute atom of id 27 and type Cl by N
# Substitute atom of id 14 and type F by Br
# Substitute atom of id 4 and type O by N
# Substitute atom of id 20 and type O by N
# Substitute atom of id 14 and type O by N
# Substitute atom of id 12 and type O by N
# Substitute atom of id 23 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 6 and type Br by O
# Substitute atom of id 20 and type O by F
# Substitute atom of id 15 and type O by Br
# Substitute atom of id 27 and type Br by N
# Substitute atom of id 13 and type Br by F
# Substitute atom of id 24 and type O by N
# Substitute atom of id 4 and type O by Br
# Substitute atom of id 27 and type Cl by Br
# Substitute atom of id 25 and type O by F
# Substitute atom of id 23 and type Br by F
# Substitute atom of id 20 and type O by F
# Substitute atom of id 20 and type O by Br
# Substitute atom of id 11 and type F by Br
# Substitute atom of id 11 and type F by N
# Substitute atom of id 28 and type Cl by N
# Substitute atom of id 17 and type O by Br
# Substitute atom of id 9 and type O by F
# Substitute atom of id 19 and type Cl by F
# Substitute atom of id 15 and type O by Br
# Substitute atom of id 27 and type Br by F
# Substitute atom of id 15 and type O by N
# Substitute atom of id 20 and type Br by F
# Substitute atom of id 25 and type O by Br
# Substitute atom of id 20 and type Br by N
# Substitute atom of id 21 and type F by N
# Substitute atom of id 3 and type O by N
# Substitute atom of id 25 and type O by Br
# Substitute atom of id 19 and type O by N
# Substitute atom of id 20 and type O by Br
# Substitute atom of id 26 and type O by F
# Substitute atom of id 12 and type N by F
# Substitute atom of id 24 and type Br by F
# Substitute atom of id 17 and type N by O
# Substitute atom of id 17 and type N by O
# Substitute atom of id 22 and type Br by N
# Substitute atom of id 14 and type O by N
# Substitute atom of id 17 and type F by N
# Substitute atom of id 10 and type O by F
# Substitute atom of id 23 and type Br by N
# Substitute atom of id 28 and type Cl by Br
# Substitute atom of id 10 and type F by O
# Substitute atom of id 10 and type F by N
# Substitute atom of id 24 and type Br by O
# Substitute atom of id 21 and type O by N
# Substitute atom of id 21 and type O by Br
# Substitute atom of id 26 and type Br by F
# Substitute atom of id 20 and type Br by O
# Substitute atom of id 19 and type Br by F
# Substitute atom of id 6 and type Br by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 22 and type Br by O
# Substitute atom of id 23 and type O by N
# Substitute atom of id 24 and type Br by F
# Substitute atom of id 22 and type O by N
# Substitute atom of id 29 and type Br by F
# Substitute atom of id 29 and type Br by N
# Substitute atom of id 27 and type F by N
# Substitute atom of id 25 and type O by Br
# Substitute atom of id 26 and type O by Br
# Substitute atom of id 26 and type O by F
# Substitute atom of id 26 and type F by N
# Substitute atom of id 15 and type Br by O
# Substitute atom of id 9 and type O by F
# Substitute atom of id 25 and type Br by O
# Substitute atom of id 16 and type Br by N
# Substitute atom of id 25 and type Br by F
# Substitute atom of id 25 and type F by N
# Substitute atom of id 15 and type Br by O
# Substitute atom of id 15 and type O by F
# Substitute atom of id 15 and type Br by O
# Substitute atom of id 16 and type F by O
# Substitute atom of id 24 and type O by N
# Substitute atom of id 8 and type Br by O
# Substitute atom of id 9 and type O by Br
# Substitute atom of id 2 and type N by O
# Substitute atom of id 25 and type Br by O
# Substitute atom of id 26 and type Br by N
# Substitute atom of id 10 and type Br by N
# Substitute atom of id 27 and type F by O
# Substitute atom of id 10 and type Br by N
# Substitute atom of id 19 and type O by Br
# Substitute atom of id 16 and type F by O
# Substitute atom of id 21 and type Br by F
# Substitute atom of id 15 and type O by N
# Substitute atom of id 5 and type F by O
# Substitute atom of id 10 and type Br by N
# Substitute atom of id 15 and type O by N
# Substitute atom of id 10 and type Br by O
# Substitute atom of id 21 and type Br by O
# Substitute atom of id 21 and type O by Br
# Substitute atom of id 17 and type F by Br
# Substitute atom of id 27 and type N by F
# Substitute atom of id 16 and type O by Br
# Substitute atom of id 23 and type Br by F
# Substitute atom of id 27 and type F by O
# Substitute atom of id 6 and type Br by F
# Substitute atom of id 28 and type O by Br
# Substitute atom of id 22 and type Br by F
# Substitute atom of id 25 and type O by N
# Substitute atom of id 18 and type F by O
# Substitute atom of id 3 and type Br by F
# Substitute atom of id 3 and type Br by O
# Substitute atom of id 3 and type O by N
# Substitute atom of id 20 and type Br by O
# Substitute atom of id 18 and type O by N
# Substitute atom of id 22 and type O by Br
# Substitute atom of id 3 and type F by O
# Substitute atom of id 22 and type O by F
# Substitute atom of id 26 and type O by N
# Substitute atom of id 18 and type O by F
# Substitute atom of id 10 and type F by N
# Substitute atom of id 10 and type F by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 18 and type O by N
# Substitute atom of id 21 and type Br by N
# Substitute atom of id 25 and type F by O
# Substitute atom of id 20 and type F by N
# Substitute atom of id 28 and type F by N
# Substitute atom of id 4 and type F by O
# Substitute atom of id 4 and type F by Br
# Substitute atom of id 28 and type F by N
# Substitute atom of id 2 and type O by N
# Substitute atom of id 10 and type N by O
# Substitute atom of id 9 and type O by F
# Substitute atom of id 17 and type O by N
# Substitute atom of id 9 and type F by Br
# Substitute atom of id 18 and type O by N
# Substitute atom of id 9 and type O by N
# Substitute atom of id 3 and type O by F
# Substitute atom of id 20 and type F by Br
# Substitute atom of id 4 and type F by N
# Substitute atom of id 20 and type F by N
# Substitute atom of id 19 and type F by N
# Substitute atom of id 28 and type F by O

# %%
pop = logger.populations[1]
compare, _, sims = compare_generated_to_reference(pop, ambigol_mols)
img = Draw.MolsToGridImage(compare, molsPerRow=2, legends=sims, returnPNG=True)
img
